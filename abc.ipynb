# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\pc\Desktop\Delivery\train_data.csv")
# Out:
#        Unnamed: 0.1  Unnamed: 0      ID  Delivery_person_Age  \
# 0                 0       21963  0x3088                 24.0
# 1                 1       10410  0x61d3                 35.0
# 2                 2       38301  0x1c3d                 38.0
# 3                 3       44997  0xc3f6                 27.0
# 4                 4       16861  0x795a                 20.0
# ...             ...         ...     ...                  ...
# 36462         36462       11284  0x7f61                 28.0
# 36463         36463       44732  0xb217                 29.0
# 36464         36464       38158  0x91b2                 24.0
# 36465         36465         860  0x1a29                 27.0
# 36466         36466       15795  0xa80a                 32.0
#
#        Delivery_person_Ratings Weather_conditions Road_traffic_density  \
# 0                          5.0              Sunny               Medium
# 1                          4.3         Sandstorms                  Low
# ...

# %%
import pickle

# Replace 'your_file.pkl' with the path to your .pkl file
file_path = r"C:\Users\pc\Desktop\Delivery\Artifact\data_transformation\procceor\feature_engg.pkl"

try:
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    print("File loaded successfully.")
    # Now 'data' contains the object saved in the .pkl file.
except FileNotFoundError:
    print(f"File '{file_path}' not found.")
except Exception as e:
    print(f"An error occurred while loading the file: {str(e)}")
# Out:
# File loaded successfully.
# c:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator Pipeline from version 1.3.0 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
data
# Out:
# Pipeline(steps=[('fe', Feature_Engineering())])
